# %%
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px
warnings.filterwarnings('ignore')

# %matplotlib inline
#%load_ext cudf.pandas
#supercharges workflow with GPU acceleration using cudf.pandas
#Im having pip install issues with cudf so commenting it out for now

# %%
pandas_df = pd.read_csv('fifa_dataset/FIFA17_official_data.csv')
pandas_df.head()
# Out:
#        ID            Name  Age  \
# 0  176580       L. Suárez   29
# 1  178518   R. Nainggolan   28
# 2  181872        A. Vidal   29
# 3  197445        D. Alaba   24
# 4  195864        P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# 3  https://cdn.sofifa.com/flags/at.png       86         89  FC Bayern München
# 4  https://cdn.sofifa.com/flags/fr.png       88         94  Manchester United
#
#                                        Club Logo  ... Marking StandingTackle  \
# 0  https://cdn.sofifa.com/teams/241/light_30.png  ...    30.0           45.0
# 1   https://cdn.sofifa.com/teams/52/light_30.png  ...    78.0           85.0
# 2   https://cdn.sofifa.com/teams/21/light_30.png  ...    76.0           89.0
# 3   https://cdn.sofifa.com/teams/21/light_30.png  ...    81.0           83.0
# 4   https://cdn.sofifa.com/teams/11/light_30.png  ...    68.0           73.0
#
#    SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes  \
# 0           38.0     27.0        25.0       31.0           33.0       37.0
# 1           88.0     11.0        11.0       14.0            8.0       11.0
# 2           84.0      4.0         2.0        4.0            2.0        4.0
# 3           83.0      5.0         7.0       14.0           15.0        9.0
# 4           73.0      5.0         6.0        2.0            4.0        3.0
#
#   Best Position Best Overall Rating
# 0            ST                88.0
# 1           CDM                84.0
# 2           CDM                85.0
# 3            LB                84.0
# 4           CAM                85.0
#
# [5 rows x 63 columns]

# %% [markdown]
# ## DATA STRUCTURE/SHAPE/INFO

# %%
pandas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17560 entries, 0 to 17559
# Data columns (total 63 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17560 non-null  int64
#  1   Name                      17560 non-null  object
#  2   Age                       17560 non-null  int64
#  3   Photo                     17560 non-null  object
#  4   Nationality               17560 non-null  object
#  5   Flag                      17560 non-null  object
#  6   Overall                   17560 non-null  int64
#  7   Potential                 17560 non-null  int64
#  8   Club                      17317 non-null  object
#  9   Club Logo                 17560 non-null  object
#  10  Value                     17560 non-null  object
#  11  Wage                      17560 non-null  object
#  12  Special                   17560 non-null  int64
#  13  Preferred Foot            17560 non-null  object
#  14  International Reputation  17560 non-null  float64
#  15  Weak Foot                 17560 non-null  float64
#  16  Skill Moves               17560 non-null  float64
#  17  Work Rate                 17560 non-null  object
#  18  Body Type                 17560 non-null  object
#  19  Real Face                 17560 non-null  object
#  20  Position                  17541 non-null  object
#  21  Jersey Number             17541 non-null  float64
#  22  Joined                    15865 non-null  object
#  23  Loaned From               1333 non-null   object
#  24  Contract Valid Until      17198 non-null  object
#  25  Height                    17560 non-null  object
#  26  Weight                    17560 non-null  object
#  27  Crossing                  17560 non-null  float64
#  28  Finishing                 17560 non-null  float64
#  29  HeadingAccuracy           17560 non-null  float64
#  30  ShortPassing              17560 non-null  float64
#  31  Volleys                   17560 non-null  float64
#  32  Dribbling                 17560 non-null  float64
#  33  Curve                     17560 non-null  float64
#  34  FKAccuracy                17560 non-null  float64
#  35  LongPassing               17560 non-null  float64
#  36  BallControl               17560 non-null  float64
#  37  Acceleration              17560 non-null  float64
#  38  SprintSpeed               17560 non-null  float64
#  39  Agility                   17560 non-null  float64
#  40  Reactions                 17560 non-null  float64
#  41  Balance                   17560 non-null  float64
#  42  ShotPower                 17560 non-null  float64
#  43  Jumping                   17560 non-null  float64
#  44  Stamina                   17560 non-null  float64
#  45  Strength                  17560 non-null  float64
#  46  LongShots                 17560 non-null  float64
#  47  Aggression                17560 non-null  float64
#  48  Interceptions             17560 non-null  float64
#  49  Positioning               17560 non-null  float64
#  50  Vision                    17560 non-null  float64
#  51  Penalties                 17560 non-null  float64
#  52  Composure                 17560 non-null  float64
#  53  Marking                   17560 non-null  float64
#  54  StandingTackle            17560 non-null  float64
#  55  SlidingTackle             17560 non-null  float64
#  56  GKDiving                  17560 non-null  float64
#  57  GKHandling                17560 non-null  float64
#  58  GKKicking                 17560 non-null  float64
#  59  GKPositioning             17560 non-null  float64
#  60  GKReflexes                17560 non-null  float64
#  61  Best Position             17560 non-null  object
#  62  Best Overall Rating       17560 non-null  float64
# dtypes: float64(39), int64(5), object(19)
# memory usage: 8.4+ MB

# %%
pandas_df.shape
# Out:
# (17560, 63)

# %%
pandas_df.dtypes
# Out:
# ID                       int64
# Name                    object
# Age                      int64
# Photo                   object
# Nationality             object
#                         ...
# GKKicking              float64
# GKPositioning          float64
# GKReflexes             float64
# Best Position           object
# Best Overall Rating    float64
# Length: 63, dtype: object

# %%
import polars as pl
polars_df = pl.read_csv('fifa_dataset/FIFA17_official_data.csv')

# %%
polars_df.head(10)
# Out:
# shape: (10, 63)
# ┌────────┬───────────────┬─────┬──────────────┬───┬──────────────┬────────────┬──────────┬─────────┐
# │ ID     ┆ Name          ┆ Age ┆ Photo        ┆ … ┆ GKPositionin ┆ GKReflexes ┆ Best     ┆ Best    │
# │ ---    ┆ ---           ┆ --- ┆ ---          ┆   ┆ g            ┆ ---        ┆ Position ┆ Overall │
# │ i64    ┆ str           ┆ i64 ┆ str          ┆   ┆ ---          ┆ f64        ┆ ---      ┆ Rating  │
# │        ┆               ┆     ┆              ┆   ┆ f64          ┆            ┆ str      ┆ ---     │
# │        ┆               ┆     ┆              ┆   ┆              ┆            ┆          ┆ f64     │
# ╞════════╪═══════════════╪═════╪══════════════╪═══╪══════════════╪════════════╪══════════╪═════════╡
# │ 176580 ┆  L. Suárez    ┆ 29  ┆ https://cdn. ┆ … ┆ 33.0         ┆ 37.0       ┆ ST       ┆ 88.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 178518 ┆ R. Nainggolan ┆ 28  ┆ https://cdn. ┆ … ┆ 8.0          ┆ 11.0       ┆ CDM      ┆ 84.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 181872 ┆  A. Vidal     ┆ 29  ┆ https://cdn. ┆ … ┆ 2.0          ┆ 4.0        ┆ CDM      ┆ 85.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 197445 ┆  D. Alaba     ┆ 24  ┆ https://cdn. ┆ … ┆ 15.0         ┆ 9.0        ┆ LB       ┆ 84.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 195864 ┆  P. Pogba     ┆ 23  ┆ https://cdn. ┆ … ┆ 4.0          ┆ 3.0        ┆ CAM      ┆ 85.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 173731 ┆  G. Bale      ┆ 26  ┆ https://cdn. ┆ … ┆ 5.0          ┆ 6.0        ┆ ST       ┆ 88.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 203551 ┆  A. Florenzi  ┆ 25  ┆ https://cdn. ┆ … ┆ 11.0         ┆ 10.0       ┆ RB       ┆ 81.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 163631 ┆  L. Baines    ┆ 31  ┆ https://cdn. ┆ … ┆ 13.0         ┆ 12.0       ┆ LWB      ┆ 81.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 177003 ┆  L. Modrić    ┆ 30  ┆ https://cdn. ┆ … ┆ 14.0         ┆ 9.0        ┆ CM       ┆ 86.0    │
# │        ┆               ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# │ 20801  ┆ Cristiano     ┆ 31  ┆ https://cdn. ┆ … ┆ 14.0         ┆ 11.0       ┆ ST       ┆ 91.0    │
# │        ┆ Ronaldo       ┆     ┆ sofifa.com/p ┆   ┆              ┆            ┆          ┆         │
# │        ┆               ┆     ┆ layers…      ┆   ┆              ┆            ┆          ┆         │
# └────────┴───────────────┴─────┴──────────────┴───┴──────────────┴────────────┴──────────┴─────────┘

# %%
polars_df.shape
# Out:
# (17560, 63)

# %%
polars_df.dtypes
# Out:
# [Int64,
#  String,
#  Int64,
#  String,
#  String,
#  String,
#  Int64,
#  Int64,
#  String,
#  String,
#  String,
#  String,
#  Int64,
#  String,
#  Float64,
#  Float64,
#  Float64,
#  String,
#  String,
#  String,
#  String,
#  Float64,
#  String,
#  String,
#  String,
#  String,
#  String,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  String,
#  Float64]

# %%
from skimpy import skim
skim(pandas_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 17560  │ │ float64     │ 39    │                                                          │
# │ │ Number of columns │ 63     │ │ string      │ 19    │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 5     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━┳━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column         ┃ NA ┃ NA %            ┃ mean   ┃ sd     ┃ p0  ┃ p25    ┃ p50    ┃ p75    ┃ p100   ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━╇━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩  │
# │ │ ID             │  0 │               0 │ 205600 │  33100 │  16 │ 191500 │ 212900 │ 229700 │ 241100 │    ▁▃▇ │  │
# │ │ Age            │  0 │               0 │  24.58 │  4.654 │  15 │     21 │     24 │     28 │     46 │  ▅▇▆▂  │  │
# │ │ Overall        │  0 │               0 │  66.16 │  7.013 │  45 │     62 │     66 │     71 │     94 │ ▁▃▇▅▁  │  │
# │ │ Potential      │  0 │               0 │  70.94 │   6.14 │  45 │     67 │     71 │     75 │     94 │  ▁▇▇▂  │  │
# │ │ Special        │  0 │               0 │   1595 │  269.9 │ 751 │   1452 │   1633 │   1786 │   2291 │ ▁▂▅▇▅  │  │
# │ │ International  │  0 │               0 │  1.112 │  0.385 │   1 │      1 │      1 │      1 │      5 │   ▇▁   │  │
# │ │ Reputation     │    │                 │        │        │     │        │        │        │        │        │  │
# │ │ Weak Foot      │  0 │               0 │  2.936 │ 0.6578 │   1 │      3 │      3 │      3 │      5 │  ▃ ▇▂  │  │
# │ │ Skill Moves    │  0 │               0 │  2.305 │  0.747 │   1 │      2 │      2 │      3 │      5 │ ▂▇ ▅▁  │  │
# │ │ Jersey Number  │ 19 │ 0.1082004555808 │  20.41 │  17.05 │   1 │      9 │     18 │     27 │     99 │  ▇▆▁   │  │
# │ │ Interceptions  │  0 │               0 │  46.75 │  20.51 │   3 │     26 │     52 │     64 │     92 │ ▃▇▃▇▇▁ │  │
# │ │ Positioning    │  0 │               0 │  49.63 │  19.39 │   2 │     38 │     54 │     64 │     94 │ ▂▂▃▇▅  │  │
# │ │ Vision         │  0 │               0 │  52.81 │  14.47 │  10 │     43 │     54 │     64 │     94 │ ▁▃▆▇▅  │  │
# │ │ Penalties      │  0 │               0 │  49.11 │  15.82 │   7 │     39 │     50 │     61 │     96 │ ▂▃▇▇▃  │  │
# │ │ Composure      │  0 │               0 │  55.98 │   13.3 │   5 │     47 │     57 │     66 │     94 │  ▁▅▇▅  │  │
# │ │ Marking        │  0 │               0 │  44.23 │  21.53 │   4 │     22 │     48 │     63 │     92 │ ▆▆▃▇▇▁ │  │
# │ │ StandingTackle │  0 │               0 │  47.46 │  21.79 │   3 │     26 │     54 │     66 │     92 │ ▃▅▃▅▇▁ │  │
# │ │ SlidingTackle  │  0 │               0 │  45.54 │  21.46 │   5 │     24 │     52 │     64 │     91 │ ▆▅▃▇▇▁ │  │
# │ │ GKDiving       │  0 │               0 │  16.81 │   17.8 │   1 │      8 │     11 │     14 │     89 │ ▇   ▁  │  │
# │ │ GKHandling     │  0 │               0 │  16.54 │  16.95 │   1 │      8 │     11 │     14 │     91 │ ▇   ▁  │  │
# │ │ GKKicking      │  0 │               0 │  16.44 │  16.59 │   1 │      8 │     11 │     14 │     95 │  ▇  ▁  │  │
# │ │ GKPositioning  │  0 │               0 │   16.6 │  17.14 │   1 │      8 │     11 │     14 │     91 │ ▇   ▁  │  │
# │ │ GKReflexes     │  0 │               0 │  16.89 │  18.03 │   1 │      8 │     11 │     14 │     90 │ ▇   ▁  │  │
# │ │ Best Overall   │  0 │               0 │  65.62 │   6.94 │  44 │     61 │     66 │     70 │     92 │  ▃▇▆▁  │  │
# │ │ Rating         │    │                 │        │        │     │        │        │        │        │        │  │
# │ └────────────────┴────┴─────────────────┴────────┴────────┴─────┴────────┴────────┴────────┴────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃          ┃       ┃          ┃          ┃          ┃          ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column   ┃ NA    ┃ NA %     ┃ shortest ┃ longest  ┃ min      ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ Name     │     0 │        0 │  PC      │  K.      │  A.      │  Óscar    │       11 │         3 │    52801 │  │
# │ │          │       │          │          │ Théophil │ Abbas    │ Whalley   │          │           │          │  │
# │ │          │       │          │          │ e-Cather │          │           │          │           │          │  │
# │ │          │       │          │          │ ine      │          │           │          │           │          │  │
# │ │ Photo    │     0 │        0 │ https:// │ https:// │ https:// │ https://c │       48 │         1 │    17560 │  │
# │ │          │       │          │ cdn.sofi │ cdn.sofi │ cdn.sofi │ dn.sofifa │          │           │          │  │
# │ │          │       │          │          │ )        │          │           │          │           │          │  │
# │ │ Real     │     0 │        0 │ No       │ Yes      │ No       │ Yes       │     2.06 │         1 │    17560 │  │
# │ │ Face     │       │          │          │          │          │           │          │           │          │  │
# │ │ Position │    19 │ 0.108200 │ <span    │ <span    │ <span    │ <span     │     26.6 │         3 │    52623 │  │
# │ │          │       │ 45558086 │ class="p │ class="p │ class="p │ class="po │          │           │          │  │
# │ │          │       │       56 │ os       │ os       │ os       │ s         │          │           │          │  │
# │ │          │       │          │ pos7">LB │ pos11">L │ pos0">GK │ pos9">RDM │          │           │          │  │
# │ │          │       │          │          │ DM       │          │           │          │           │          │  │
# │ │ Joined   │  1695 │ 9.652619 │ Jan 7,   │ Jul 11,  │ Apr 1,   │ Sep 9,    │     11.4 │       2.7 │    47595 │  │
# │ │          │       │ 58997722 │ 2014     │ 2014     │ 2006     │ 2016      │          │           │          │  │
# │ │ Loaned   │ 16227 │ 92.40888 │ <a       │ <a       │ <a       │ <a        │     50.4 │      0.22 │     3876 │  │
# │ │ From     │       │ 38268792 │ href="/t │ href="/t │ href="/t │ href="/te │          │           │          │  │
# │ │          │       │        8 │ eam/247/ │ eam/1101 │ eam/1/ar │ am/983/su │          │           │          │  │
# │ │          │       │          │ psv/">PS │ 45/tibur │ senal/"> │ won-samsu │          │           │          │  │
# │ │          │       │          │ V</a>    │ ones-roj │ Arsenal< │ ng-bluewi │          │           │          │  │
# │ │          │       │          │          │ os-de-ve │ /a>      │ ngs/">Suw │          │           │          │  │
# │ │          │       │          │          │ racruz/" │          │ on        │          │           │          │  │
# │ │          │       │          │          │ >Tiburon │          │ Samsung   │          │           │          │  │
# │ │          │       │          │          │ es Rojos │          │ Bluewings │          │           │          │  │
# │ │          │       │          │          │ de       │          │ </a>      │          │           │          │  │
# │ │          │       │          │          │ Veracruz │          │           │          │           │          │  │
# │ │          │       │          │          │ </a>     │          │           │          │           │          │  │
# │ │ Contract │   362 │ 2.061503 │ 2021     │ Jun 30,  │ 2017     │ Sep 5,    │     4.62 │       1.1 │    19864 │  │
# │ │ Valid    │       │ 41685649 │          │ 2017     │          │ 2018      │          │           │          │  │
# │ │ Until    │       │        2 │          │          │          │           │          │           │          │  │
# │ │ Height   │     0 │        0 │ 6'0      │ 5'11     │ 5'1      │ 6'9       │     3.27 │         1 │    17560 │  │
# │ │ Weight   │     0 │        0 │ 190lbs   │ 190lbs   │ 106lbs   │ 243lbs    │        6 │         1 │    17560 │  │
# │ │ Best     │     0 │        0 │ ST       │ CDM      │ CAM      │ ST        │     2.22 │         1 │    17560 │  │
# │ │ Position │       │          │          │          │          │           │          │           │          │  │
# │ └──────────┴───────┴──────────┴──────────┴──────────┴──────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
#skimpy supports polars dataframes as well
skim(polars_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 17560  │ │ float64     │ 39    │                                                          │
# │ │ Number of columns │ 63     │ │ string      │ 19    │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 5     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━
# │ │ GKPositioning  │  0 │               0 │   16.6 │  17.14 │   1 │      8 │     11 │     14 │     91 │ ▇   ▁  │  │
# │ │ GKReflexes     │  0 │               0 │  16.89 │  18.03 │   1 │      8 │     11 │     14 │     90 │ ▇   ▁  │  │
# │ │ Best Overall   │  0 │               0 │  65.62 │   6.94 │  44 │     61 │     66 │     70 │     92 │  ▃▇▆▁  │  │
# │ │ Rating         │    │                 │        │        │     │        │        │        │        │        │  │
# │ └────────────────┴────┴─────────────────┴────────┴────────┴─────┴────────┴────────┴────────┴────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃          ┃     ┃           ┃          ┃           ┃          ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column   ┃ NA  ┃ NA %      ┃ shortest ┃ longest   ┃ min      ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━╇━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ Name     │   0 │         0 │  PC      │  K.       │  A.      │  Óscar    │       11 │         3 │    52801 │  │
# │ │          │     │           │          │ Théophile │ Abbas    │ Whalley   │          │           │          │  │
# │ │          │     │           │          │ -Catherin │          │           │          │           │          │  │
# │ │          │     │           │          │ e         │          │           │          │           │          │  │
# │ │ Photo    │   0 │         0 │ https:// │ https://c │ https:// │ https://c │       48 │         1 │    17560 │  │
# │ │          │     │           │ cdn.sofi │ dn.sofifa │ cdn.sofi │ dn.sofifa │          │           │          │  │
# │ │          │     │           │ fa.com/p │ .com/play │ fa.com/p │ .com/play │          │           │          │  │
# │ │          │     │           │ layers/1 │ ers/176/5 │ layers/0 │ ers/241/0 │          │           │          │  │
# │ │          │     │           │ 76/580/1 │ 80/17_60. │ 00/016/1 │ 56/17_60. │          │           │          │  │
# │ │          │     │           │ 7_60.png │ png       │ 7_60.png │ png       │          │           │          │  │
# │ │ National │   0 │         0 │ Cuba     │ Central   │ Afghanis │ Zimbabwe  │     7.67 │       1.1 │    20129 │  │
# │ │ ity      │     │           │          │ African   │ tan      │           │          │           │          │  │
# │ │          │     │           │          │ Republic  │          │           │          │           │          │  │
# │ │ Flag     │   0 │         0 │ https:// │ https://c │ https:// │ https://c │     35.5 │         1 │    17560 │  │
# │ │          │     │           │ cdn.sofi │ dn.sofifa │ cdn.sofi │ dn.sofifa │          │           │          │  │
# │ │          │     │           │ fa.com/f │ .com/flag │ fa.com/f │ .com/flag │          │           │          │  │
# │ │          │     │           │ lags/uy. │ s/gb-wls. │ lags/af. │ s/zw.png  │          │           │          │  │
# │ │          │     │           │ png      │ png       │ png      │           │          │           │          │  │
# │ │ Club     │ 243 │ 1.3838268 │ PSV      │ Football  │ 1. FC    │ Śląsk     │     13.3 │       2.1 │    36921 │  │
# │ │          │     │ 792710706 │          │ Bourg En  │ Heidenhe │ Wrocław   │          │           │          │  │
# │ │          │     │           │          │ Bresse    │ im 1846  │           │          │           │          │  │
# │ │          │     │           │          │ Peronnas  │          │           │          │           │          │  │
# │ │          │     │           │          │ 01        │          │           │          │           │          │  │
# │ │ Club     │   0 │         0 │ https:// │ https://c │ https:// │ https://c │     46.2 │         1 │    17560 │  │
# │ │ Logo     │     │           │ cdn.sofi │ dn.sofifa │ cdn.sofi │ dn.sofifa │          │           │          │  │
# │ │          │     │           │ fa.com/f │ .com/team │ fa.com/f │ .com/team │          │           │          │  │
# │ │          │     │           │ lags/br. │ s/101059/ │ lags/ar. │ s/983/lig │          │           │          │  │
# │ │          │     │           │ png      │ light_30. │ png      │ ht_30.png │          │           │          │  │
# │ │          │     │           │          │ png       │          │           │          │           │          │  │
# │ │ Value    │   0 │         0 │ €0       │ €37.5M    │ €0       │ €9M       │     4.78 │         1 │    17560 │  │
# │ │ Wage     │   0 │         0 │ €0       │ €525K     │ €0       │ €9K       │     3.34 │         1 │    17560 │  │
# │ │ Preferre │   0 │         0 │ Left     │ Right     │ Left     │ Right     │     4.77 │         1 │    17560 │  │
# │ │ d Foot   │     │           │          │           │          │           │          │           │          │  │
# │ │ Work     │   0 │         0 │ Low/ Low │ Medium/   │ High/    │ Medium/   │     12.7 │         2 │    35120 │  │
# │ │ Rate     │     │           │          │ Medium    │ High     │ Medium    │          │           │          │  │
# │ │ Body     │   0 │         0 │ Messi    │ Normal    │ Akinfenw │ Stocky    │     14.2 │         2 │    35115 │  │
# │ │ Type     │     │           │          │ (170-185) │ a        │ (185+)    │          │           │          │  │
# │ │ Real     │   0 │         0 │ No       │ Yes       │ No       │ Yes       │     2.06 │         1 │    17560 │  │
# │ │ Face     │     │           │          │           │          │           │          │           │          │  │
# │ │ Position │   0 │         0 │ nan      │ <span     │ <span    │ nan       │     26.6 │         3 │    52642 │  │
# │ │          │     │           │          │ class="po │ class="p │           │          │           │          │  │
# │ │          │     │           │          │ s         │ os       │           │          │           │          │  │
# │ │          │     │           │          │ pos11">LD │ pos0">GK │           │          │           │          │  │
# │ │          │     │           │          │ M         │          │           │          │           │          │  │
# │ │ Joined   │   0 │         0 │ nan      │ Jul 11,   │ Apr 1,   │ nan       │     10.6 │       2.8 │    49290 │  │
# │ │          │     │           │          │ 2014      │ 2006     │           │          │           │          │  │
# │ │ Loaned   │   0 │         0 │ nan      │ <a        │ <a       │ nan       │      6.6 │       1.1 │    20103 │  │
# │ │ From     │     │           │          │ href="/te │ href="/t │           │          │           │          │  │
# │ │          │     │           │          │ am/110145 │ eam/1/ar │           │          │           │          │  │
# │ │          │     │           │          │ /tiburone │ senal/"> │           │          │           │          │  │
# │ │          │     │           │          │ s-rojos-d │ Arsenal< │           │          │           │          │  │
# │ │          │     │           │          │ e-veracru │ /a>      │           │          │           │          │  │
# │ │          │     │           │          │ z/">Tibur │          │           │          │           │          │  │
# │ │          │     │           │          │ ones      │          │           │          │           │          │  │
# │ │          │     │           │          │ Rojos de  │          │           │          │           │          │  │
# │ │          │     │           │          │ Veracruz< │          │           │          │           │          │  │
# │ │          │     │           │          │ /a>       │          │           │          │           │          │  │
# │ │ Contract │   0 │         0 │ nan      │ Jun 30,   │ 2017     │ nan       │     4.59 │       1.2 │    20226 │  │
# │ │ Valid    │     │           │          │ 2017      │          │           │          │           │          │  │
# │ │ Until    │     │           │          │           │          │           │          │           │          │  │
# │ │ Height   │   0 │         0 │ 6'0      │ 5'11      │ 5'1      │ 6'9       │     3.27 │         1 │    17560 │  │
# │ │ Weight   │   0 │         0 │ 190lbs   │ 190lbs    │ 106lbs   │ 243lbs    │        6 │         1 │    17560 │  │
# │ │ Best     │   0 │         0 │ ST       │ CDM       │ CAM      │ ST        │     2.22 │         1 │    17560 │  │
# │ │ Position │     │           │          │           │          │           │          │           │          │  │
# │ └──────────┴─────┴───────────┴──────────┴───────────┴──────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
from summarytools import dfSummary
dfSummary(pandas_df)
# Out:
# <style type="text/css">
# #T_bb686 thead>tr>th {
#   text-align: left;
# }
# #T_bb686_row0_col0, #T_bb686_row1_col0, #T_bb686_row2_col0, #T_bb686_row3_col0, #T_bb686_row4_col0, #T_bb686_row5_col0, #T_bb686_row6_col0, #T_bb686_row7_col0, #T_bb686_row8_col0, #T_bb686_row9_col0, #T_bb686_row10_col0, #T_bb686_row11_col0, #T_bb686_row12_col0, #T_bb686_row13_col0, #T_bb686_row14_col0, #T_bb686_row15_col0, #T_bb686_row16_col0, #T_bb686_row17_col0, #T_bb686_row18_col0, #T_bb686_row19_col0, #T_bb686_row20_col0, #T_bb686_row21_col0, #T_bb686_row22_col0, #T_bb686_row23_col0, #T_bb686_row24_col0, #T_bb686_row25_col0, #T_bb686_row26_col0, #T_bb686_row27_col0, #T_bb686_row28_col0, #T_bb686_row29_col0, #T_bb686_row30_col0, #T_bb686_row31_col0, #T_bb686_row32_col0, #T_bb686_row33_col0, #T_bb686_row34_col0, #T_bb686_row35_col0, #T_bb686_row36_col0, #T_bb686_row37_col0, #T_bb686_row38_col0, #T_bb686_row39_col0, #T_bb686_row40_col0, #T_bb686_row41_col0, #T_bb686_row42_col0, #T_bb686_row43_col0, #T_bb686_row44_col0, #T_bb686_row45_col0, #T_bb686_row46_col0, #T_bb686_row47_col0, #T_bb686_row48_col0, #T_bb686_row49_col0, #T_bb686_row50_col0, #T_bb686_row51_col0, #T_bb686_row52_col0, #T_bb686_row53_col0, #T_bb686_row54_col0, #T_bb686_row55_col0, #T_bb686_row56_col0, #T_bb686_row57_col0, #T_bb686_row58_col0, #T_bb686_row59_col0, #T_bb686_row60_col0, #T_bb686_row61_col0, #T_bb686_row62_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_bb686_row0_col1, #T_bb686_row1_col1, #T_bb686_row2_col1, #T_bb686_row3_col1, #T_bb686_row4_col1, #T_bb686_row5_col1, #T_bb686_row6_col1, #T_bb686_row7_col1, #T_bb686_row8_col1, #T_bb686_row9_col1, #T_bb686_row10_col1, #T_bb686_row11_col1, #T_bb686_row12_col1, #T_bb686_row13_col1, #T_bb686_row14_col1, #T_bb686_row15_col1, #T_bb686_row
col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_bb686_row0_col5, #T_bb686_row1_col5, #T_bb686_row2_col5, #T_bb686_row3_col5, #T_bb686_row4_col5, #T_bb686_row5_col5, #T_bb686_row6_col5, #T_bb686_row7_col5, #T_bb686_row8_col5, #T_bb686_row9_col5, #T_bb686_row10_col5, #T_bb686_row11_col5, #T_bb686_row12_col5, #T_bb686_row13_col5, #T_bb686_row14_col5, #T_bb686_row15_col5, #T_bb686_row16_col5, #T_bb686_row17_col5, #T_bb686_row18_col5, #T_bb686_row19_col5, #T_bb686_row20_col5, #T_bb686_row21_col5, #T_bb686_row22_col5, #T_bb686_row23_col5, #T_bb686_row24_col5, #T_bb686_row25_col5, #T_bb686_row26_col5, #T_bb686_row27_col5, #T_bb686_row28_col5, #T_bb686_row29_col5, #T_bb686_row30_col5, #T_bb686_row31_col5, #T_bb686_row32_col5, #T_bb686_row33_col5, #T_bb686_row34_col5, #T_bb686_row35_col5, #T_bb686_row36_col5, #T_bb686_row37_col5, #T_bb

# %%
#summarytools does not support polars dataframes
dfSummary(polars_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 #summarytools does not support polars dataframes
# ----> 2 dfSummary(polars_df)
#
# File c:\Users\admin\anaconda3\Lib\site-packages\summarytools\summary.py:55, in dfSummary(data, max_level, show_graph, tmp_dir, is_collapsible, num_proc)
#      25 """generate HTML data summary
#      26
#      27 Args:
#    (...)
#      51 ```
#      52 """
#      54 tbl_name = _var_name(data)
# ---> 55 tbl_dups = f"Duplicates: {data.duplicated().sum():,}"
#      56 tbl_dims = "Dimensions: {:,} x {:,}".format(*data.shape)
#      57 tbl_caption = "<strong>Data Frame Summary</strong><br>"
#
# AttributeError: 'DataFrame' object has no attribute 'duplicated'

# %% [markdown]
# ## NULL VALUES

# %%
#only club has null values
polars_df.null_count()
# Out:
# shape: (1, 63)
# ┌─────┬──────┬─────┬───────┬───┬───────────────┬────────────┬───────────────┬─────────────────────┐
# │ ID  ┆ Name ┆ Age ┆ Photo ┆ … ┆ GKPositioning ┆ GKReflexes ┆ Best Position ┆ Best Overall Rating │
# │ --- ┆ ---  ┆ --- ┆ ---   ┆   ┆ ---           ┆ ---        ┆ ---           ┆ ---                 │
# │ u32 ┆ u32  ┆ u32 ┆ u32   ┆   ┆ u32           ┆ u32        ┆ u32           ┆ u32                 │
# ╞═════╪══════╪═════╪═══════╪═══╪═══════════════╪════════════╪═══════════════╪═════════════════════╡
# │ 0   ┆ 0    ┆ 0   ┆ 0     ┆ … ┆ 0             ┆ 0          ┆ 0             ┆ 0                   │
# └─────┴──────┴─────┴───────┴───┴───────────────┴────────────┴───────────────┴─────────────────────┘

# %%
pandas_df.isna().sum().sort_values(ascending=False).head(20)
pandas_df.duplicated().sum(), pandas_df.duplicated(subset=['Name']).sum()  # adjust subset keys
pandas_df.select_dtypes('object').nunique().sort_values(ascending=False).head(20)  # high-cardinality cats
# Out:
# Photo                   17560
# Name                    16596
# Joined                   1720
# Club Logo                 663
# Club                      632
# Loaned From               316
# Value                     203
# Nationality               160
# Flag                      160
# Weight                     56
# Wage                       41
# Contract Valid Until       34
# Position                   29
# Height                     21
# Body Type                  16
# Best Position              15
# Work Rate                   9
# Preferred Foot              2
# Real Face                   2
# dtype: int64

# %%
#heatmap of missing values shows only club has missing values of type MCAR (Missing Completely at Random)
#I want to understand the pattern of missingness, why is the data missing?
#nan values in "loaned from" column are because the player is not on loan
#nan values in "club" column are because the player is a free agent
plt.figure(figsize=(12, 6))
sns.heatmap(pandas_df.isna(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
#dropping columns that are not useful for analysis
#these columns are images and logos links which do not add value to the analysis
col = ['Photo','Flag','Club Logo']
fifa = pandas_df.drop(columns = col, axis = 1)
fifa.shape
# Out:
# (17560, 60)

# %%
#Clean position column as it has some junk span classes data
#What is difference between position and best position?
#Convert value and wage to numeric
#What is the special column?
#Body type has easter egg values like "Messi" and "C. Ronaldo"
#Convert height and weight to numeric
#Convert work rate to categorical low, medium, high
#Convert joined date to datetime
#Find Loan Sharks from loaned from column

# %%
#Clean position column
import re

pattern = re.compile(r">([^<]+)$")  # capture everything between > and <

fifa["Position_clean"] = fifa["Position"].apply(
    lambda x: pattern.search(str(x)).group(1) if pd.notna(x) and pattern.search(str(x)) else None
)

print(fifa[["Position", "Position_clean", "Best Position"]].head(10))
# Out:
#                       Position Position_clean Best Position
# 0   <span class="pos pos25">ST             ST            ST
# 1   <span class="pos pos22">LF             LF           CDM
# 2  <span class="pos pos11">LDM            LDM           CDM
# 3    <span class="pos pos7">LB             LB            LB
# 4  <span class="pos pos11">LDM            LDM           CAM
# 5   <span class="pos pos23">RW             RW            ST
# 6  <span class="pos pos28">SUB            SUB            RB
# 7    <span class="pos pos7">LB             LB           LWB
# 8  <span class="pos pos13">RCM            RCM            CM
# 9   <span class="pos pos27">LW             LW            ST

# %%
#Number of players where Position != Best Position: 115
diff_df = fifa[fifa['Position_clean'] != fifa['Best Position']]
print(f"Number of players where Position != Best Position: {len(diff_df)}")
print(diff_df[['Name', 'Position_clean', 'Best Position']].head(10))
# Out:
# Number of players where Position != Best Position: 15241
#                   Name Position_clean Best Position
# 1        R. Nainggolan             LF           CDM
# 2             A. Vidal            LDM           CDM
# 4             P. Pogba            LDM           CAM
# 5              G. Bale             RW            ST
# 6          A. Florenzi            SUB            RB
# 7            L. Baines             LB           LWB
# 8            L. Modrić            RCM            CM
# 9    Cristiano Ronaldo             LW            ST
# 10        C. Marchisio            SUB            CM
# 11             D. Srna             RB            CM

# %%
#Convert value and wage to numeric
def convert(df_value):
    try:
        # If already a float or int, return as is
        if isinstance(df_value, (float, int)):
            return df_value
        # If not a string, return 0
        if not isinstance(df_value, str):
            return 0
        # Remove currency symbol and commas
        s = df_value.replace('€', '').replace(',', '').strip().upper()
        if s == '':
            return 0
        # Handle suffix
        if s[-1] == 'M':
            value = float(s[:-1]) * 1_000_000
        elif s[-1] == 'K':
            value = float(s[:-1]) * 1_000
        else:
            value = float(s)
    except Exception:
        value = 0
    return value

fifa['Value'] = fifa['Value'].apply(convert)
fifa['Wage'] = fifa['Wage'].apply(convert)
fifa.head()
# Out:
#        ID            Name  Age Nationality  Overall  Potential  \
# 0  176580       L. Suárez   29     Uruguay       92         92
# 1  178518   R. Nainggolan   28     Belgium       86         86
# 2  181872        A. Vidal   29       Chile       87         87
# 3  197445        D. Alaba   24     Austria       86         89
# 4  195864        P. Pogba   23      France       88         94
#
#                 Club       Value      Wage  Special  ... StandingTackle  \
# 0       FC Barcelona  83000000.0  525000.0     2291  ...           45.0
# 1               Roma  37500000.0  130000.0     2290  ...           85.0
# 2  FC Bayern München  41500000.0  180000.0     2285  ...           89.0
# 3  FC Bayern München  41500000.0  140000.0     2279  ...           83.0
# 4  Manchester United  71500000.0  225000.0     2271  ...           73.0
#
#    SlidingTackle  GKDiving  GKHandling GKKicking GKPositioning GKReflexes  \
# 0           38.0      27.0        25.0      31.0          33.0       37.0
# 1           88.0      11.0        11.0      14.0           8.0       11.0
# 2           84.0       4.0         2.0       4.0           2.0        4.0
# 3           83.0       5.0         7.0      14.0          15.0        9.0
# 4           73.0       5.0         6.0       2.0           4.0        3.0
#
#   Best Position  Best Overall Rating Position_clean
# 0            ST                 88.0             ST
# 1           CDM                 84.0             LF
# 2           CDM                 85.0            LDM
# 3            LB                 84.0             LB
# 4           CAM                 85.0            LDM
#
# [5 rows x 61 columns]

# %%
#What is the special column?
fifa['Special'].describe()
# Out:
# count    17560.000000
# mean      1595.468223
# std        269.862012
# min        751.000000
# 25%       1452.000000
# 50%       1633.000000
# 75%       1786.000000
# max       2291.000000
# Name: Special, dtype: float64

# %%
# Summary statistics for the Special column
print(fifa['Special'].describe())

# Distribution plot for Special
plt.figure(figsize=(10,5))
sns.histplot(fifa['Special'], bins=30, kde=True)
plt.title('Distribution of Special Attribute')
plt.xlabel('Special')
plt.show()

# Top 10 players by Special
top_special = fifa.nlargest(10, 'Special')[['Name', 'Special', 'Overall', 'Potential', 'Club']]
print(top_special)
# Out:
# count    17560.000000
# mean      1595.468223
# std        269.862012
# min        751.000000
# 25%       1452.000000
# 50%       1633.000000
# 75%       1786.000000
# max       2291.000000
# Name: Special, dtype: float64
#                  Name  Special  Overall  Potential               Club
# 0           L. Suárez     2291       92         92       FC Barcelona
# 1       R. Nainggolan     2290       86         86               Roma
# 2            A. Vidal     2285       87         87  FC Bayern München
# 3            D. Alaba     2279       86         89  FC Bayern München
# 4            P. Pogba     2271       88         94  Manchester United
# 5             G. Bale     2266       90         90        Real Madrid
# 6         A. Florenzi     2264       82         85               Roma
# 7           L. Baines     2245       83         83            Everton
# 8           L. Modrić     2231       89         89        Real Madrid
# 9   Cristiano Ronaldo     2223       94         94        Real Madrid

# %%
# Special column is a column which is just like overall but with more granularity
# It ranges from 47 to 2200 with mean of 611. It is likely a composite score based on various attributes
# It helps to differentiate players with same overall rating by providing a more detailed score

# %%
# Body type has easter egg values like "Messi" and "C. Ronaldo"
# Unique values in Body Type column
print(fifa['Body Type'].unique())

# Find rows with Body Type as 'Messi' or 'C. Ronaldo'
easter_eggs = fifa[fifa['Body Type'].isin(['Messi', 'C. Ronaldo', 'Shaqiri', 'Neymar', 'Akinfenwa', 'Courtois'])]
print(easter_eggs[['Name', 'Body Type', 'Overall', 'Special', 'Club']])
# Out:
# ['Normal (170-185)' 'Stocky (170-185)' 'Lean (170-185)' 'Lean (185+)'
#  'Normal (170-)' 'C. Ronaldo' 'Normal (185+)' 'Messi' 'Stocky (170-)'
#  'Lean (170-)' 'Shaqiri' 'Neymar' 'Normal (190+)' 'Stocky (185+)'
#  'Akinfenwa' 'Courtois']
#                      Name   Body Type  Overall  Special               Club
# 9       Cristiano Ronaldo  C. Ronaldo       94     2223        Real Madrid
# 58               L. Messi       Messi       93     2155       FC Barcelona
# 120            X. Shaqiri     Shaqiri       82     2117         Stoke City
# 168                Neymar      Neymar       92     2098       FC Barcelona
# 10997        A. Akinfenwa   Akinfenwa       64     1552  Wycombe Wanderers
# 15266         T. Courtois    Courtois       89     1282            Chelsea

# %%
fifa['Height'] = pandas_df['Height']
fifa['Weight'] = pandas_df['Weight']
print(fifa[['Height', 'Weight']].head(10))
# Out:
#   Height  Weight
# 0    6'0  190lbs
# 1    5'9  143lbs
# 2   5'11  165lbs
# 3   5'11  168lbs
# 4    6'3  185lbs
# 5    6'0  163lbs
# 6    5'8  148lbs
# 7    5'7  154lbs
# 8    5'9  143lbs
# 9    6'1  176lbs

# %%
def height_conversion(height):
    try:
        if pd.isna(height):
            return np.nan
        # Remove spaces and handle strings like "5'9"
        height_str = str(height).replace(" ", "")
        if "'" in height_str:
            ft, inch = height_str.split("'")
            ft = float(ft)
            inch = float(inch) if inch else 0
        else:
            # If only feet provided, no inches
            ft = float(height_str)
            inch = 0
        total_cm = (ft * 12 + inch) * 2.54
        return total_cm
    except Exception:
        return np.nan

fifa['Height'] = fifa['Height'].apply(height_conversion)
fifa['Height'] = fifa['Height'].fillna(fifa['Height'].mean())
print(fifa['Height'].head())
# Out:
# 0    182.88
# 1    175.26
# 2    180.34
# 3    180.34
# 4    190.50
# Name: Height, dtype: float64

# %%
value = float(fifa['Weight'][0][0:-3])*0.453592
print('%0.2f'%value)

#in kg
def weight_conversion(weight):
    if(pd.isna(weight))!= True:
        w = int(weight[0:-3])*0.453592
        return w
    else:
        return weight

fifa['Weight'] = fifa['Weight'].apply(weight_conversion)

fifa['Weight'] = fifa['Weight'].fillna(value = fifa['Weight'].mean())

fifa['Weight'][13230:13239]
# Out:
# 86.18
# 13230    69.853168
# 13231    84.821704
# 13232    68.945984
# 13233    71.213944
# 13234    78.925008
# 13235    79.832192
# 13236    76.203456
# 13237    81.192968
# 13238    77.110640
# Name: Weight, dtype: float64

# %%
#Convert height and weight to numeric, i.e into cms and kgs respectfully
print(fifa[['Height', 'Weight']].head(10))
# Out:
#    Height     Weight
# 0  182.88  86.182480
# 1  175.26  64.863656
# 2  180.34  74.842680
# 3  180.34  76.203456
# 4  190.50  83.914520
# 5  182.88  73.935496
# 6  172.72  67.131616
# 7  170.18  69.853168
# 8  175.26  64.863656
# 9  185.42  79.832192

# %%
fifa['Joined'] = pandas_df['Joined']

# %%
#Convert joined date to datetime
def date_conversion(date):
    if pd.isna(date):
        return np.nan
    if isinstance(date, str):
        try:
            val = date.split(',')
            # If format is like "Jul 1, 2016", get the year
            year = int(val[1]) if len(val) > 1 else np.nan
            return year
        except Exception:
            return np.nan
    return np.nan

fifa['Joined'] = fifa['Joined'].apply(date_conversion)
print(fifa['Joined'].head(10))
# Out:
# 0    2014.0
# 1    2014.0
# 2    2015.0
# 3    2010.0
# 4    2016.0
# 5    2013.0
# 6    2010.0
# 7    2007.0
# 8    2012.0
# 9    2009.0
# Name: Joined, dtype: float64

# %%
#Convert work rate to categorical low, medium, high
def work_rate_conversion(rate):
    if pd.isna(rate):
        return (np.nan, np.nan)
    if isinstance(rate, str) and '/' in rate:
        try:
            attack, defense = rate.split('/')
            return (attack.strip(), defense.strip())
        except Exception:
            return (np.nan, np.nan)
    return (np.nan, np.nan)

fifa[['Attacking Work Rate', 'Defensive Work Rate']] = fifa['Work Rate'].apply(work_rate_conversion).apply(pd.Series)
fifa[['Work Rate', 'Attacking Work Rate', 'Defensive Work Rate']].head(10)
# Out:
#       Work Rate Attacking Work Rate Defensive Work Rate
# 0  High/ Medium                High              Medium
# 1    High/ High                High                High
# 2    High/ High                High                High
# 3  High/ Medium                High              Medium
# 4  High/ Medium                High              Medium
# 5  High/ Medium                High              Medium
# 6  High/ Medium                High              Medium
# 7  High/ Medium                High              Medium
# 8  High/ Medium                High              Medium
# 9     High/ Low                High                 Low

# %%
#Clean the loaned from column
import re

pattern = re.compile(r">(.*?)<")  # capture everything between > and <

fifa["Loaned From_clean"] = fifa["Loaned From"].apply(
    lambda x: pattern.search(str(x)).group(1) if pd.notna(x) and pattern.search(str(x)) else None
)

print(fifa[["Loaned From", "Loaned From_clean"]].head(10))

#it will show Nan/None for players who are not on loan
#other unique values are clubs from which players are loaned come later up in the dataset
# Out:
#   Loaned From Loaned From_clean
# 0         NaN              None
# 1         NaN              None
# 2         NaN              None
# 3         NaN              None
# 4         NaN              None
# 5         NaN              None
# 6         NaN              None
# 7         NaN              None
# 8         NaN              None
# 9         NaN              None

# %%
#Find Loan Sharks from loaned from column
fifa['Loaned From_clean'].value_counts().head(10)
# Out:
# Loaned From_clean
# Roma                      19
# Atalanta                  18
# Juventus                  16
# Inter                     16
# Chievo Verona             15
# San Lorenzo de Almagro    14
# Lazio                     14
# FC Porto                  14
# SL Benfica                14
# Udinese                   14
# Name: count, dtype: int64

# %% [markdown]
# ## Final Fifa Dataset Looks like

# %%
fifa.head(10)
# Out:
#        ID                Name  Age Nationality  Overall  Potential  \
# 0  176580           L. Suárez   29     Uruguay       92         92
# 1  178518       R. Nainggolan   28     Belgium       86         86
# 2  181872            A. Vidal   29       Chile       87         87
# 3  197445            D. Alaba   24     Austria       86         89
# 4  195864            P. Pogba   23      France       88         94
# 5  173731             G. Bale   26       Wales       90         90
# 6  203551         A. Florenzi   25       Italy       82         85
# 7  163631           L. Baines   31     England       83         83
# 8  177003           L. Modrić   30     Croatia       89         89
# 9   20801   Cristiano Ronaldo   31    Portugal       94         94
#
#                 Club       Value      Wage  Special  ... GKHandling  \
# 0       FC Barcelona  83000000.0  525000.0     2291  ...       25.0
# 1               Roma  37500000.0  130000.0     2290  ...       11.0
# 2  FC Bayern München  41500000.0  180000.0     2285  ...        2.0
# 3  FC Bayern München  41500000.0  140000.0     2279  ...        7.0
# 4  Manchester United  71500000.0  225000.0     2271  ...        6.0
# 5        Real Madrid  72000000.0  375000.0     2266  ...       15.0
# 6               Roma  20500000.0   70000.0     2264  ...        8.0
# 7            Everton  14500000.0  100000.0     2245  ...       15.0
# 8        Real Madrid  54000000.0  325000.0     2231  ...        9.0
# 9        Real Madrid  87000000.0  575000.0     2223  ...       11.0
#
#    GKKicking  GKPositioning  GKReflexes Best Position Best Overall Rating  \
# 0       31.0           33.0        37.0            ST                88.0
# 1       14.0            8.0        11.0           CDM                84.0
# 2        4.0            2.0         4.0           CDM                85.0
# 3       14.0           15.0         9.0            LB                84.0
# 4        2.0            4.0         3.0           CAM                85.0
# 5       11.0            5.0         6.0            ST                88.0
# 6       10.0           11.0        10.0            RB                81.0
# 7       10.0           13.0        12.0           LWB                81.0
# 8        7.0           14.0         9.0            CM                86.0
# 9       15.0           14.0        11.0            ST                91.0
#
#   Position_clean Attacking Work Rate  Defensive Work Rate  Loaned From_clean
# 0             ST                High               Medium               None
# 1             LF                High                 High               None
# 2            LDM                High                 High               None
# 3             LB                High               Medium               None
# 4            LDM                High               Medium               None
# 5             RW                High               Medium               None
# 6            SUB                High               Medium               None
# 7             LB                High               Medium               None
# 8            RCM                High               Medium               None
# 9             LW                High                  Low               None
#
# [10 rows x 64 columns]

# %%
skim(fifa)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 17560  │ │ float64     │ 44    │                                                          │
# │ │ Number of columns │ 64     │ │ string      │ 15    │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 5     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column     ┃ NA   ┃ NA %      ┃ mean    ┃ sd      ┃ p0    ┃ p25    ┃ p50    ┃ p75     ┃ p100      ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━┩  │
# │ │ ID         │    0 │         0 │  205600 │   33100 │    16 │ 191500 │ 212900 │  229700 │    241100 │    ▁▃▇ │  │
# │ │ Age        │    0 │         0 │   24.58 │   4.654 │    15 │     21 │     24 │      28 │        46 │  ▅▇▆▂  │  │
# │ │ Overall    │    0 │         0 │   66.16 │   7.013 │    45 │     62 │     66 │      71 │        94 │ ▁▃▇▅▁  │  │
# │ │ Potential  │    0 │         0 │   70.94 │    6.14 │    45 │     67 │     71 │      75 │        94 │  ▁▇▇▂  │  │
# │ │ ckle       │      │           │         │         │       │        │        │         │           │        │  │
# │ │ SlidingTac │    0 │         0 │   45.54 │   21.46 │     5 │     24 │     52 │      64 │        91 │ ▆▅▃▇▇▁ │  │
# │ │ kle        │      │           │         │         │       │        │        │         │           │        │  │
# │ │ GKDiving   │    0 │         0 │   16.81 │    17.8 │     1 │      8 │     11 │      14 │        89 │ ▇   ▁  │  │
# │ │ GKHandling │    0 │         0 │   16.54 │   16.95 │     1 │      8 │     11 │      14 │        91 │ ▇   ▁  │  │
# │ │ GKKicking  │    0 │         0 │   16.44 │   16.59 │     1 │      8 │     11 │      14 │        95 │  ▇  ▁  │  │
# │ │ GKPosition │    0 │         0 │    16.6 │   17.14 │     1 │      8 │     11 │      14 │        91 │ ▇   ▁  │  │
# │ │ ing        │      │           │         │         │       │        │        │         │           │        │  │
# │ │ GKReflexes │    0 │         0 │   16.89 │   18.03 │     1 │      8 │     11 │      14 │        90 │ ▇   ▁  │  │
# │ │ Best       │    0 │         0 │   65.62 │    6.94 │    44 │     61 │     66 │      70 │        92 │  ▃▇▆▁  │  │
# │ │ Overall    │      │           │         │         │       │        │        │         │           │        │  │
# │ │ Rating     │      │           │         │         │       │        │        │         │           │        │  │
# │ └────────────┴──────┴───────────┴─────────┴─────────┴───────┴────────┴────────┴─────────┴───────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃          ┃       ┃          ┃          ┃          ┃          ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column   ┃ NA    ┃ NA %     ┃ shortest ┃ longest  ┃ min      ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ Name     │     0 │        0 │  PC      │  K.      │  A.      │  Óscar    │       11 │         3 │    52801 │  │
# │ │          │       │          │          │ Théophil │ Abbas    │ Whalley   │          │           │          │  │
# │ │          │       │          │          │ e-Cather │          │           │          │           │          │  │
# │ │          │       │          │          │ ine      │          │           │          │           │          │  │
# │ │ National │     0 │        0 │ Cuba     │ Central  │ Afghanis │ Zimbabwe  │     7.67 │       1.1 │    20129 │  │
# │ │ ity      │       │          │          │ African  │ tan      │           │          │           │          │  │
# │ │          │       │          │          │ Republic │          │           │          │           │          │  │
# │ │ Club     │   243 │ 1.383826 │ PSV      │ Football │ 1. FC    │ Śląsk     │     13.3 │       2.1 │    36921 │  │
# │ │          │       │ 87927107 │          │ Bourg En │ Heidenhe │ Wrocław   │          │           │          │  │
# │ │          │       │       06 │          │ Bresse   │ im 1846  │           │          │           │          │  │
# │ │          │       │          │          │ Peronnas │          │           │          │           │          │  │
# │ │          │       │          │          │ 01       │          │           │          │           │          │  │
# │ │ Preferre │     0 │        0 │ Left     │ Right    │ Left     │ Right     │     4.77 │         1 │    17560 │  │
# │ │ d Foot   │       │          │          │          │          │           │          │           │          │  │
# │ │ Work     │     0 │        0 │ Low/ Low │ Medium/  │ High/    │ Medium/   │     12.7 │         2 │    35120 │  │
# │ │ Rate     │       │          │          │ Medium   │ High     │ Medium    │          │           │          │  │
# │ │ Body     │     0 │        0 │ Messi    │ Normal   │ Akinfenw │ Stocky    │     14.2 │         2 │    35115 │  │
# │ │ Type     │       │          │          │ (170-185 │ a        │ (185+)    │          │           │          │  │
# │ │          │       │          │          │ )        │          │           │          │           │          │  │
# │ │ Real     │     0 │        0 │ No       │ Yes      │ No       │ Yes       │     2.06 │         1 │    17560 │  │
# │ │ Face     │       │          │          │          │          │           │          │           │          │  │
# │ │ Position │    19 │ 0.108200 │ <span    │ <span    │ <span    │ <span     │     26.6 │         3 │    52623 │  │
# │ │          │       │ 45558086 │ class="p │ class="p │ class="p │ class="po │          │           │          │  │
# │ │          │       │       56 │ os       │ os       │ os       │ s         │          │           │          │  │
# │ │          │       │          │ pos7">LB │ pos11">L │ pos0">GK │ pos9">RDM │          │           │          │  │
# │ │          │       │          │          │ DM       │          │           │          │           │          │  │
# │ │ Loaned   │ 16227 │ 92.40888 │ <a       │ <a       │ <a       │ <a        │     50.4 │      0.22 │     3876 │  │
# │ │ From     │       │ 38268792 │ href="/t │ href="/t │ href="/t │ href="/te │          │           │          │  │
# │ │          │       │        8 │ eam/247/ │ eam/1101 │ eam/1/ar │ am/983/su │          │           │          │  │
# │ │          │       │          │ psv/">PS │ 45/tibur │ senal/"> │ won-samsu │          │           │          │  │
# │ │          │       │          │ V</a>    │ ones-roj │ Arsenal< │ ng-bluewi │          │           │          │  │
# │ │          │       │          │          │ os-de-ve │ /a>      │ ngs/">Suw │          │           │          │  │
# │ │          │       │          │          │ racruz/" │          │ on        │          │           │          │  │
# │ │          │       │          │          │ >Tiburon │          │ Samsung   │          │           │          │  │
# │ │          │       │          │          │ es Rojos │          │ Bluewings │          │           │          │  │
# │ │          │       │          │          │ de       │          │ </a>      │          │           │          │  │
# │ │          │       │          │          │ Veracruz │          │           │          │           │          │  │
# │ │          │       │          │          │ </a>     │          │           │          │           │          │  │
# │ │ Contract │   362 │ 2.061503 │ 2021     │ Jun 30,  │ 2017     │ Sep 5,    │     4.62 │       1.1 │    19864 │  │
# │ │ Valid    │       │ 41685649 │          │ 2017     │          │ 2018      │          │           │          │  │
# │ │ Until    │       │        2 │          │          │          │           │          │           │          │  │
# │ │ Best     │     0 │        0 │ ST       │ CDM      │ CAM      │ ST        │     2.22 │         1 │    17560 │  │
# │ │ Position │       │          │          │          │          │           │          │           │          │  │
# │ │ Position │    19 │ 0.108200 │ ST       │ LDM      │ CAM      │ SUB       │     2.78 │         1 │    17541 │  │
# │ │ _clean   │       │ 45558086 │          │          │          │           │          │           │          │  │
# │ │          │       │       56 │          │          │          │           │          │           │          │  │
# │ │ Attackin │     0 │        0 │ Low      │ Medium   │ High     │ Medium    │     5.34 │         1 │    17560 │  │
# │ │ g Work   │       │          │          │          │          │           │          │           │          │  │
# │ │ Rate     │       │          │          │          │          │           │          │           │          │  │
# │ │ Defensiv │     0 │        0 │ Low      │ Medium   │ High     │ Medium    │     5.41 │         1 │    17560 │  │
# │ │ e Work   │       │          │          │          │          │           │          │           │          │  │
# │ │ Rate     │       │          │          │          │          │           │          │           │          │  │
# │ │ Loaned   │ 16227 │ 92.40888 │ PSV      │ Tiburone │ 1. FC    │ Zenit St. │       12 │      0.14 │     2543 │  │
# │ │ From_cle │       │ 38268792 │          │ s Rojos  │ Nürnberg │ Petersbur │          │           │          │  │
# │ │ an       │       │        8 │          │ de       │          │ g         │          │           │          │  │
# │ │          │       │          │          │ Veracruz │          │           │          │           │          │  │
# │ └──────────┴───────┴──────────┴──────────┴──────────┴──────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## Graphs(temp)

# %%
sns.relplot(data=pandas_df, x='Overall', y='Potential', hue='Position', kind='scatter', height=6, aspect=1.5)
plt.title('Overall vs Potential by Position')
plt.show()

# %%
from ipywidgets import interact

pd.options.plotting.backend = 'plotly'

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=pandas_df)
plt.title('Line Plot of All Numerical Features')
plt.show()

# %%
#highest potential players
top_potential = pandas_df.nlargest(10, 'Potential')[['Name', 'Overall', 'Potential', 'Club', 'Wage']]
print("Top 10 Players by Potential:")
print(top_potential)
# Out:
# Top 10 Players by Potential:
#                      Name  Overall  Potential               Club   Wage
# 4                P. Pogba       88         94  Manchester United  €225K
# 9       Cristiano Ronaldo       94         94        Real Madrid  €575K
# 168                Neymar       92         94       FC Barcelona  €450K
# 58               L. Messi       93         93       FC Barcelona  €575K
# 284             P. Dybala       86         93           Juventus  €180K
# 0               L. Suárez       92         92       FC Barcelona  €525K
# 657             K. Mbappé       79         92          AS Monaco   €40K
# 12372            M. Neuer       92         92  FC Bayern München  €225K
# 13739              De Gea       90         92  Manchester United  €190K
# 15266         T. Courtois       89         92            Chelsea  €170K

# %%
# Distribution of Potential ratings
sns.distplot(fifa['Potential'], bins=10, color='r')
plt.title("Distribution of Potential\n ratings of all Players")
plt.savefig("Distribution.png")
plt.show()

# %%
#highest overall players
top_overall = pandas_df.nlargest(10, 'Overall')[['Name', 'Overall', 'Potential', 'Club', 'Wage']]
print("Top 10 Players by Overall:")
print(top_overall)
# Out:
# Top 10 Players by Overall:
#                      Name  Overall  Potential               Club   Wage
# 9       Cristiano Ronaldo       94         94        Real Madrid  €575K
# 58               L. Messi       93         93       FC Barcelona  €575K
# 0               L. Suárez       92         92       FC Barcelona  €525K
# 168                Neymar       92         94       FC Barcelona  €450K
# 12372            M. Neuer       92         92  FC Bayern München  €225K
# 5                 G. Bale       90         90        Real Madrid  €375K
# 109        R. Lewandowski       90         90  FC Bayern München  €250K
# 118        Z. Ibrahimović       90         90  Manchester United  €300K
# 13739              De Gea       90         92  Manchester United  €190K
# 8               L. Modrić       89         89        Real Madrid  €325K

# %%
# Distribution of Overall ratings
sns.distplot(fifa['Overall'], bins=10, color='r')
plt.title("Distribution of Overall ratings of all Players")
plt.savefig("Distribution.png")
plt.show()
